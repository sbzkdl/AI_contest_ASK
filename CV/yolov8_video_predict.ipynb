# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import ultralytics
import json

# %%
model = YOLO('/content/drive/MyDrive/AI_contest/yolov8m_runs/detect/train2/weights/best.pt')

# %%
model.predict('/content/drive/MyDrive/AI_contest/WIN_20231212_15_31_39_Pro.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/165) /content/drive/MyDrive/AI_contest/WIN_20231212_15_31_39_Pro.mp4: 384x640 1 base, 26.0ms
# video 1/1 (2/165) /content/drive/MyDrive/AI_contest/WIN_20231212_15_31_39_Pro.mp4: 384x640 1 base, 28.3ms
# video 1/1 (3/165) /content/drive/MyDrive/AI_contest/WIN_20231212_15_31_39_Pro.mp4: 384x640 1 base, 25.7ms
# video 1/1 (4/165) /content/drive/MyDrive/AI_contest/WIN_20231212_15_31_39_Pro.mp4: 384x640 1 base, 25.8ms
# ...
