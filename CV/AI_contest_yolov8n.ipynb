# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="n3ss2Hsh6ubYkK4PpC5Z")
project = rf.workspace("aihackathon").project("face-l5wsk")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import yaml

with open('/content/Face-1/data.yaml', 'r') as f:
  origin = yaml.safe_load(f)

categories = origin['names']

# %%
data = { 'train' : '/content/Face-1/train/images/',
         'val' : '/content/Face-1/valid/images/',
         'test' : '/content/Face-1/test/images/',
         'names' : categories,
         'nc' : 3 }

with open('/content/Face-1/face_data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('/content/Face-1/face_data.yaml', 'r') as f:
  face_yaml = yaml.safe_load(f)
  display(face_yaml)
# Out:
# {'names': ['base', 'child', 'senior'],
#  'nc': 3,
#  'test': '/content/Face-1/test/images/',
#  'train': '/content/Face-1/train/images/',
#  'val': '/content/Face-1/valid/images/'}

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 73.0MB/s]

# %%
model.train(data='/content/Face-1/face_data.yaml', epochs=100, patience=30, batch=32, imgsz=640, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.0.226 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
predict_model = YOLO('/content/drive/MyDrive/AI_contest/runs/detect/train/weights/best.pt')

# %%
def tojson(self, normalize=False):
    """Convert the object to JSON format."""
    if self.probs is not None:
        LOGGER.warning('Warning: Classify task do not support `tojson` yet.')
        return

    import json

    # Create list of detection dictionaries
    results = []
    data = self.boxes.data.cpu().tolist()
    h, w = self.orig_shape if normalize else (1, 1)
    for i, row in enumerate(data):  # xyxy, track_id if tracking, conf, class_id
        box = {'x1': row[0] / w, 'y1': row[1] / h, 'x2': row[2] / w, 'y2': row[3] / h}
        conf = row[-2]
        class_id = int(row[-1])
        name = self.names[class_id]
        result = {'name': name, 'class': class_id, 'confidence': conf, 'box': box}
        if self.boxes.is_track:
            result['track_id'] = int(row[-3])  # track ID
        if self.masks:
            x, y = self.masks.xy[i][:, 0], self.masks.xy[i][:, 1]  # numpy array
            result['segments'] = {'x': (x / w).tolist(), 'y': (y / h).tolist()}
        if self.keypoints is not None:
            x, y, visible = self.keypoints[i].data[0].cpu().unbind(dim=1)  # torch Tensor
            result['keypoints'] = {'x': (x / w).tolist(), 'y': (y / h).tolist(), 'visible': visible.tolist()}
        results.append(result)

    # Convert detections to JSON
    return json.dumps(results, indent=2)

# %%
results = predict_model('/content/drive/MyDrive/AI_contest/lovepik-grandpa-and-grandson-snuggle-together-picture_501161204.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/AI_contest/lovepik-grandpa-and-grandson-snuggle-together-picture_501161204.jpg: 448x640 1 child, 1 senior, 63.9ms
# Speed: 3.4ms preprocess, 63.9ms inference, 11.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
import json

to_json = tojson(results[0])
json_object = json.loads(to_json)
json_object
# Out:
# [{'name': 'child',
#   'class': 1,
#   'confidence': 0.8526098132133484,
#   'box': {'x1': 449.07293701171875,
#    'y1': 234.5886993408203,
#    'x2': 609.063720703125,
#    'y2': 410.09283447265625}},
#  {'name': 'senior',
#   'class': 2,
#   'confidence': 0.8502059578895569,
#   'box': {'x1': 625.0733032226562,
#    'y1': 135.74551391601562,
#    'x2': 828.44189453125,
#    'y2': 433.4938659667969}}]

# %%
class_list = []

for i in range(len(json_object)):
    name = json_object[i]['name']
    if name in class_list:
        pass
    else:
        class_list.append(name)

class_list
# Out:
# ['child', 'senior']
