# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="n3ss2Hsh6ubYkK4PpC5Z")
project = rf.workspace("aihackathon").project("face-l5wsk")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 805.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import yaml

with open('/content/Face-2/data.yaml', 'r') as f:
  origin = yaml.safe_load(f)

categories = origin['names']

# %%
data = { 'train' : '/content/Face-2/train/images/',
         'val' : '/content/Face-2/valid/images/',
        #  'test' : '/content/Face-2/test/images/',
         'names' : categories,
         'nc' : 3 }

with open('/content/Face-2/face_data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('/content/Face-2/face_data.yaml', 'r') as f:
  face_yaml = yaml.safe_load(f)
  display(face_yaml)
# Out:
# {'names': ['base', 'child', 'senior'],
#  'nc': 3,
#  'train': '/content/Face-2/train/images/',
#  'val': '/content/Face-2/valid/images/'}

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 112MB/s]

# %%
model.train(data='/content/Face-2/face_data.yaml', epochs=100, patience=30, batch=32, imgsz=640, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.0.226 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
predict_model = YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
def tojson(self, normalize=False):
    """Convert the object to JSON format."""
    if self.probs is not None:
        LOGGER.warning('Warning: Classify task do not support `tojson` yet.')
        return

    import json

    # Create list of detection dictionaries
    results = []
    data = self.boxes.data.cpu().tolist()
    h, w = self.orig_shape if normalize else (1, 1)
    for i, row in enumerate(data):  # xyxy, track_id if tracking, conf, class_id
        box = {'x1': row[0] / w, 'y1': row[1] / h, 'x2': row[2] / w, 'y2': row[3] / h}
        conf = row[-2]
        class_id = int(row[-1])
        name = self.names[class_id]
        result = {'name': name, 'class': class_id, 'confidence': conf, 'box': box}
        if self.boxes.is_track:
            result['track_id'] = int(row[-3])  # track ID
        if self.masks:
            x, y = self.masks.xy[i][:, 0], self.masks.xy[i][:, 1]  # numpy array
            result['segments'] = {'x': (x / w).tolist(), 'y': (y / h).tolist()}
        if self.keypoints is not None:
            x, y, visible = self.keypoints[i].data[0].cpu().unbind(dim=1)  # torch Tensor
            result['keypoints'] = {'x': (x / w).tolist(), 'y': (y / h).tolist(), 'visible': visible.tolist()}
        results.append(result)

    # Convert detections to JSON
    return json.dumps(results, indent=2)

# %%
results = predict_model('/content/drive/MyDrive/AI_contest/20150511090657_633228_2666_4000.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/AI_contest/20150511090657_633228_2666_4000.jpg: 640x448 1 child, 1 senior, 27.5ms
# Speed: 3.6ms preprocess, 27.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)

# %%
import json

to_json = tojson(results[0])
json_object = json.loads(to_json)
json_object
# Out:
# [{'name': 'senior',
#   'class': 2,
#   'confidence': 0.9280686378479004,
#   'box': {'x1': 348.3529052734375,
#    'y1': 223.3290557861328,
#    'x2': 540.486572265625,
#    'y2': 491.43780517578125}},
#  {'name': 'child',
#   'class': 1,
#   'confidence': 0.7911291122436523,
#   'box': {'x1': 155.6210479736328,
#    'y1': 334.939208984375,
#    'x2': 324.2884826660156,
#    'y2': 522.3079223632812}}]

# %%
class_list = []

for i in range(len(json_object)):
    name = json_object[i]['name']
    if name in class_list:
        pass
    else:
        class_list.append(name)

class_list
# Out:
# ['senior', 'child']

# %%
predict_model.predict('/content/drive/MyDrive/AI_contest/20150511090657_633228_2666_4000.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/AI_contest/20150511090657_633228_2666_4000.jpg: 640x448 1 child, 1 senior, 117.4ms
# Speed: 3.6ms preprocess, 117.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'base', 1: 'child', 2: 'senior'}
#  orig_img: array([[[210, 213, 221],
#          [207, 210, 218],
#          [204, 209, 218],
#          ...,
#          [242, 244, 244],
#          [249, 249, 249],
#          [252, 252, 252]],
#
#         [[214, 217, 225],
#          [216, 219, 227],
#          [221, 223, 233],
#          ...,
#          [241, 243, 243],
#          [247, 247, 247],
#          [250, 250, 250]],
#
#         [[227, 230, 235],
#          [223, 227, 232],
#          [227, 230, 238],
#          ...,
#          [241, 242, 240],
#          [246, 244, 243],
# ...
